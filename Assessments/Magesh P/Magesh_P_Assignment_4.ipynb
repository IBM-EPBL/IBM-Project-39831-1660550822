# %% [markdown]
# NAME: MAGESH P
# REG NO: 511319104046
# TEAM ID:PNT2022TMID39901
# PROJECT TITLE:Exploratory Analysis of Rain Fall Data in India for Agriculture.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,f1_score
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### load dataset

# %%
data=pd.read_csv('Mall_Customers.csv')

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.info
# Out:
# <bound method DataFrame.info of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# ### Data Visualizations

# %%
sns.distplot(data["Age"],color="Pink")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(data["Gender"],color="Pink")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.barplot(y= 'CustomerID',
  x= 'Age',
data =data,
           errwidth=0.1,
           n_boot=2,orient='v',)

plt.xticks(rotation=90,horizontalalignment='right',
           fontweight='light',fontsize=6)
plt.xlabel('CustomerID',size=15)
plt.ylabel('Age',size=15)

plt.figure(figsize=(500,500))
plt.show()

# %%
sns.barplot(y= 'Annual Income (k$)',
  x= 'Spending Score (1-100)',
 data =data,
           errwidth=0.1,
           n_boot=2,orient='v',)

plt.xticks(rotation=90,horizontalalignment='right',
           fontweight='light',fontsize=6)
plt.xlabel('Annual Income (k$)',size=15)
plt.ylabel('Spending Score (1-100)',size=15)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(8,9))
sns.scatterplot(x=data["Age"],y=data['Gender'],hue=data["Spending Score (1-100)"],
                palette="flare", size=data["Spending Score (1-100)"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
fig,ax=plt.subplots(figsize=(8,7))
sns.stripplot(x=data["Age"],y=data["Gender"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
sns.pairplot(data,hue="Spending Score (1-100)", diag_kind="hist")

# %%
sns.heatmap(data.corr(),cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Descriptive statistics

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ### missing values

# %%
data.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
import missingno as msno 
msno.matrix(data,color=(1,0.76,0.78),fontsize=25)
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
data=data.drop(columns=["CustomerID"],axis=1)

# %%
sns.boxplot(data.Age,color="Pink")
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(data['Annual Income (k$)'],color="Pink")
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
p1=data['Annual Income (k$)'].quantile(0.99)
p1
# Out:
# 126.1099999999999

# %%
data=data[data['Annual Income (k$)']<=p1]

# %%
sns.boxplot(data['Annual Income (k$)'],color="Pink")
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)'>

# %%
sns.boxplot(data['Spending Score (1-100)'],color="Pink")
# Out:
# <AxesSubplot:xlabel='Spending Score (1-100)'>

# %% [markdown]
# ### Categorial cloumns

# %%
le=LabelEncoder()

# %%
data.Gender=le.fit_transform(data.Gender)

# %%
data.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %% [markdown]
# ### Clustering

# %%
X = data.iloc[:, -3:]
km = KMeans(n_clusters=5).fit(X)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(X.iloc[:, 1], X.iloc[:, 2], hue=km.labels_ , palette="husl")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(X.iloc[:, 0], X.iloc[:, 1], hue=km.labels_ ,palette="husl")
plt.show()

# %%
S = data.loc[:, ["Age", "Gender", "Annual Income (k$)"]]
k = KMeans(n_clusters=6)

sns.relplot(x="Gender", y="Age", hue="Annual Income (k$)", data=S, height=6,palette="flare");

# %% [markdown]
# ### spliting data

# %%
X = data.iloc[:,0:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 1)
x_train.shape
# Out:
# (158, 3)

# %%
y_train.shape
# Out:
# (158,)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
y_test.shape
# Out:
# (40,)

# %%
x_train.head()
# Out:
#      Gender  Age  Annual Income (k$)
# 107       1   54                  63
# 106       0   66                  63
# 56        0   51                  44
# 14        1   37                  20
# 113       1   19                  64

# %%
y_train.head()
# Out:
# 107    46
# 106    50
# 56     50
# 14     13
# 113    46
# Name: Spending Score (1-100), dtype: int64

# %% [markdown]
# ### Scaling

# %%
x_scale=pd.DataFrame(scale(data),columns=data.columns)
x_scale.head()
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0  1.141195 -1.425414           -1.779171               -0.435989
# 1  1.141195 -1.282367           -1.779171                1.199413
# 2 -0.876275 -1.353890           -1.739447               -1.720949
# 3 -0.876275 -1.139319           -1.739447                1.043661
# 4 -0.876275 -0.567131           -1.699723               -0.397051

# %% [markdown]
# ### Build a model

# %%
from sklearn.ensemble import RandomForestClassifier
Rmodel=RandomForestClassifier(n_estimators=100)

# %% [markdown]
# ### Train a model

# %%
Rmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Test  the model

# %%
ypred=Rmodel.predict(x_test)
ypred2=Rmodel.predict(x_train)

# %%
print(accuracy_score(y_test,ypred))
# Out:
# 0.025

# %%
print(accuracy_score(y_train,ypred2))
# Out:
# 0.9746835443037974

# %%
f1_score(ypred,y_test,average='weighted')
# Out:
# 0.025
